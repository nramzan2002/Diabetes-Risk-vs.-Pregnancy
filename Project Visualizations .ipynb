# %%
import pandas as pd
import seaborn as sns

# %%
# Import CSV File
data = pd.read_csv('Healthcare-Diabetes.csv')

# %%
data.head(10)
# Out:
#    Pregnancies  Glucose
# 0            6      148
# 1            1       85
# 2            8      183
# 3            1       89
# 4            0      137
# 5            5      116
# 6            3       78
# 7           10      115
# 8            2      197
# 9            8      125

# %%
data.columns
# Out:
# Index(['Pregnancies', 'Glucose'], dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
data.plot?

# %%
data.dtypes
# Out:
# Pregnancies    int64
# Glucose        int64
# dtype: object

# %%
data.index
# Out:
# RangeIndex(start=0, stop=2768, step=1)

# %%
data.shape
# Out:
# (2768, 2)

# %%
data.describe()
# Out:
#        Pregnancies      Glucose
# count  2768.000000  2768.000000
# mean      3.742775   121.102601
# std       3.323801    32.036508
# min       0.000000     0.000000
# 25%       1.000000    99.000000
# 50%       3.000000   117.000000
# 75%       6.000000   141.000000
# max      17.000000   199.000000

# %%
data.columns
# Out:
# Index(['Pregnancies', 'Glucose'], dtype='object')

# %%
plt.scatter(data['Glucose'], data['Pregnancies'], color = "purple")
plt.xlabel('Glucose')
plt.ylabel('Pregnancies')
plt.title('Number of Pregnancies vs. Glucose Levels')
plt.show()

# %%
plt.barh(data['Pregnancies'], data['Glucose'], color = 'pink')
plt.xlabel('Glucose')
plt.ylabel('Pregnancies')
plt.title('Number of Pregnancies vs. Glucose Levels')
plt.show()
